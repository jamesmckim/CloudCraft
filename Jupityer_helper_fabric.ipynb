# %%
from fabrictestbed_extensions.fablib.fablib import FablibManager
fablib = FablibManager()

fablib.delete_slice("k8s-game-cluster")
# Out:
# User: JM1029804@wcupa.edu bastion key is valid!
# Configuration is valid

# %%
fablib.list_slices()
# Out:
# <style type="text/css">
# #T_31e84 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_31e84 th {
#   text-align: left;
# }
# #T_31e84 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_31e84 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_31e84 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_31e84_row0_col0, #T_31e84_row0_col1, #T_31e84_row0_col2, #T_31e84_row0_col3, #T_31e84_row0_col4, #T_31e84_row0_col5, #T_31e84_row0_col6, #T_31e84_row0_col7 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_31e84">
#   <caption>Slices</caption>
#   <thead>
#     <tr>
#       <th id="T_31e84_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_31e84_level0_col1" class="col_heading level0 col1" >Name</th>
# ...

# %%
sed -i 's/\r$//' deploy_everything.sh
# Out:
#   Cell In[3], line 1
#     sed -i 's/\r$//' deploy_everything.sh
#            ^
# SyntaxError: invalid syntax

# %%
./deploy_everything.sh https://github.com/jamesmckim/CloudCraft.git
